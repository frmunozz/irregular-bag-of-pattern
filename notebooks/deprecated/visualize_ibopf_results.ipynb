# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
results_path = "/home/francisco/Documents/tesis/data/results/plasticc/"
df = pd.read_csv(os.path.join(results_path, "ibopf_config_A.csv"))
df2 = df.sort_values(by=["mean_test_score"], ascending=False)
df2.iloc[:40]
# Out:
#        Unnamed: 0 class_feature   scheme reducer_type  param_ext__idx  \
# 21655       21655        type-2  ltc.ltc          lsa              53
# 22979       22979        type-2  ntc.ntc          lsa              53
# 21659       21659        type-2  ltc.ltc          lsa              53
# 21657       21657        type-2  ltc.ltc          lsa              53
# 22978       22978        type-2  ntc.ntc          lsa              53
# 22977       22977        type-2  ntc.ntc          lsa              53
# 21654       21654        type-2  ltc.ltc          lsa              53
# 21658       21658        type-2  ltc.ltc          lsa              53
# 22974       22974        type-2  ntc.ntc          lsa              53
# 26939       26939        type-2  ltn.ltn          lsa              53
# 22975       22975        type-2  ntc.ntc          lsa              53
# 22976       22976        type-2  ntc.ntc          lsa              53
# ...

# %%
df2[df2["reducer_type"] == "anova"]
# Out:
#        Unnamed: 0 class_feature   scheme reducer_type  param_ext__idx  \
# 23639       23639        type-2  ntc.ntc        anova              53
# 22319       22319        type-2  ltc.ltc        anova              53
# 23638       23638        type-2  ntc.ntc        anova              53
# 22317       22317        type-2  ltc.ltc        anova              53
# 22318       22318        type-2  ltc.ltc        anova              53
# ...           ...           ...      ...          ...             ...
# 11287       11287        type-1  ltc.ltc        anova               6
# 11286       11286        type-1  ltc.ltc        anova               6
# 11285       11285        type-1  ltc.ltc        anova               6
# 11284       11284        type-1  ltc.ltc        anova               6
# 11283       11283        type-1  ltc.ltc        anova               6
#
#        param_red__sc     window  word_length  mean_test_score  std_test_score  \
# ...
